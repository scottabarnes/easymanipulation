# %%
# ! pip install seaborn
# ! pip install utility_package

# %%
import seaborn as sns

# %%
import utility_package as util

# %%
df = sns.load_dataset('iris')

# %%
util.describe_data(df)
# Out:
#           field data_type  number_null prop_null count unique         top freq
# 0  sepal_length   float64            0        0%   150     35         5.0   10
# 1   sepal_width   float64            0        0%   150     23         3.0   26
# 2  petal_length   float64            0        0%   150     43         1.5   13
# 3   petal_width   float64            0        0%   150     22         0.2   29
# 4       species    object            0        0%   150      3  versicolor   50

# %%
df_grp = df.groupby(['species']).agg(**{'number_species':('species','count')}).reset_index()
df_grp['proportion'] = df_grp['number_species'] / df_grp['number_species'].sum()
df_grp['proportion'] = df_grp['proportion'].apply(up.as_percent)
df_grp
# Out:
#       species  number_species proportion
# 0      setosa              50     33.33%
# 1  versicolor              50     33.33%
# 2   virginica              50     33.33%

# %%
up.col_val_distr(df,'species')
# Out:
#   species_values  count percentage
# 0     versicolor     50      33.3%
# 1      virginica     50      33.3%
# 2         setosa     50      33.3%

# %%
up.filteronnulls(df,'species')
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, species]
# Index: []

# %%
up.pretty_value_counts(df,'species')
# Out:
#       species  count proportion prop_cumul_sum
# 0  versicolor     50     33.33%         33.33%
# 1   virginica     50     33.33%         66.67%
# 2      setosa     50     33.33%        100.00%

# %%
up.camel_case_cols(df)
df
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
up.display_and_show_all(df)
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width     Species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...
